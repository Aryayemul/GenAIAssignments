# %% [markdown]
# Implement all Prompt Engineering approaches- Interview Approach, COT, TOT. Compare
# and contrast all and analyse their applications.  Implement Zero shot and Few shot prompting
# and compare their results.

# %%
import google.generativeai as genai
import time

# %%
genai.configure(api_key="AIzaSyAEWBOYYCibbI1jL9j_FWsWoppIJd3Wedc")

# %%
model = genai.GenerativeModel("models/gemma-3-27b-it")

# %%
def run_prompt(title,prompt):
    print("\n==============================")
    print(title)
    print("==============================")

    response = model.generate_content(prompt)
    print(response.text)

    time.sleep(1)

# %% [markdown]
# ## Zero - Shot Prompting

# %%
zero_shot_prompt = """
Classify the sentiment of the sentence as Positive, Negative, or Neutral.

Sentence: The movie was fantastic and very entertaining.
"""


run_prompt("Zero Shot Prompting",zero_shot_prompt)
# Out:
# ...
# Zero Shot Prompting
# ...
# **Positive**
#
# The words "fantastic" and "entertaining" both carry strong positive connotations.

# %% [markdown]
# Few Shot Prompting

# %%
few_shot_prompt = """
Classify the sentiment.

Example 1:
Sentence: I love this phone.
Sentiment: Positive

Example 2:
Sentence: This product is terrible.
Sentiment: Negative

Sentence: The movie was fantastic and very entertaining.
Sentiment:
"""

run_prompt("FEW SHOT PROMPTING", few_shot_prompt)
# Out:
# ...
# FEW SHOT PROMPTING
# ...
# Positive

# %% [markdown]
# ## Chain of Thought(COT)

# %%
cot_prompt = """
Solve step by step.

If a train travels 60 km per hour for 5 hours,
how far will it travel?
"""

run_prompt("CHAIN OF THOUGHT", cot_prompt)
# Out:
# ...
# CHAIN OF THOUGHT
# ...
# Here's how to solve the problem step-by-step:
#
# * **Understand the relationship:** Distance = Speed x Time
# * **Identify the speed:** The train travels at 60 km/hour.
# * **Identify the time:** The train travels for 5 hours.
# * **Calculate the distance:** Distance = 60 km/hour * 5 hours = 300 km
#
# **Answer:** The train will travel 300 km.

# %% [markdown]
# ## Tree-of-Thought (TOT)

# %%
tot_prompt = """
Consider multiple solutions before deciding.

You need to travel 300 km.

Options:
1. Car
2. Train
3. Flight

Evaluate each based on:
- Cost
- Time
- Convenience

Then choose the best option.
"""

run_prompt("TREE OF THOUGHT", tot_prompt)
# Out:
# ...
# TREE OF THOUGHT
# ...
# Okay, let's break down each travel option for a 300km journey, considering cost, time, and convenience.  I'll try to be realistic, acknowledging that costs and times can *vary significantly* based on specifics (fuel prices, train class, airport location, etc.).  I'll provide ranges and assumptions.
#
# **1. Car**
#
# *   **Cost:** This is variable. Let's assume:
#     *   Fuel: 300km at, say, 10L/100km = 30L.  At $1.70/L (a reasonable average), that's $51.
#     *   Wear & Tear:  Hard to quantify precisely, but let's estimate $0.10/km = $30.  (This covers oil changes, tire wear, etc.)
#     *   Potential Tolls:  Could be $0 - $20 depending on the route. Let's average $10.
#     *   Parking at destination: $0 - $30 (depending on location). Let's average $15.
#     *   **Total Estimated Cost:** $51 + $30 + $10 + $15 = **$106** (Range: $86 - $166)
# *   **Time:**
#     *   Driving Time: 300km at an average speed of 100km/h = 3 hours.
# ...

# %% [markdown]
# ## Interview Approach

# %%
interview_prompt = """
You are a fitness coach.

Ask the user these questions before creating a workout plan:

1. Age
2. Fitness goal
3. Current fitness level
4. Workout days available
5. Any health conditions
"""

run_prompt("INTERVIEW APPROACH", interview_prompt)
# Out:
# ...
# INTERVIEW APPROACH
# ...
# Alright, let's get you moving towards your fitness goals! To create the *best* workout plan for *you*, I need a little information first. Don't worry, this is just to make sure everything is safe and effective.
#
# Please answer these questions as honestly as possible:
#
# 1. **Age:** (Just a number helps me tailor the intensity!)
# 2. **Fitness Goal:** What are you hoping to achieve? (e.g., weight loss, muscle gain, improved endurance, general fitness, training for a specific event?)
# 3. **Current Fitness Level:** Be realistic! Choose one that best describes you:
#     * **Beginner:** Little to no regular exercise.
#     * **Intermediate:** Exercise 2-3 times a week, comfortable with basic movements.
#     * **Advanced:** Exercise 4+ times a week, familiar with a variety of exercises and training techniques.
# ...
